# %% [markdown]
# <a href="https://colab.research.google.com/github/AlfinHeck/UAS_VISI_KOMPUTER/blob/main/Fitur_Tekstur.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import Library nya

# %%
#impor library yang diperlukan
import cv2
import numpy as np
import matplotlib.pyplot as plt
import glob

from skimage.color import rgb2gray
from skimage.feature import local_binary_pattern

# %% [markdown]
# Mensetting tata letak/lokasi folder yang dituju

# %%
#membuat fungsi load_image
def load_image(arr):
    strr = "Datasets/*.jpg"
    for file in glob.glob(strr):
        img=np.asarray(plt.imread(file))
        arr.append(img)
    return arr

# %% [markdown]
# fungsi preprocessing(). Fungsi ini bertujuan untuk memproses dataset kita menjadi gambar skala keabuan.

# %%
#membuat fungsi preprocessing
def preprocessing(arr):
    arr_prep=[]
    for i in range(np.shape(arr)[0]):
        img=cv2.cvtColor(arr[i], cv2.COLOR_BGR2GRAY)
        arr_prep.append(img)
    return arr_prep

# %% [markdown]
# Tujuan dari fungsi ini adalah mengembalikan 2 nilai. Nilai pertama adalah hasil ekstraksi tekstur dalam bentuk gambar. Dan nilai kedua adalah hasil ekstraksi tekstur dalam bentuk vektor.

# %%
#membuat fungsi extractLBP
def extractLBP(img):
    lbp = local_binary_pattern(img, 24,3, method="uniform")
    (hist, _) = np.histogram(lbp.ravel(),bins=np.arange(0, 27),range=(0, 26))
    hist = hist.astype("float")
    hist /= (hist.sum() + (1e-7))
    return lbp,hist

# %% [markdown]
# Fungsi ini bertujuan untuk mengembalikan array baru yang berisi tekstur yang diekstraksi, beserta vektornya.

# %%
#membuat fungsi featureextraction
def featureExtraction(arr):
    arr_feature=[]
    vector_feature=[]
    for i in range(np.shape(arr)[0]):
        lb,vektor = extractLBP(arr[i])
        arr_feature.append(lb)
        vector_feature.append(vektor)
    return arr_feature, vector_feature

# %% [markdown]
# memuat dataset dan menyimpannya dalam array

# %%
#memuat dataset
data=[]
data=load_image(data)

# %% [markdown]
# Proses data ke gambar greyscale

# %%
#merubah gambar ke greyscale
dataPreprocessed = preprocessing(data)

# %% [markdown]
# Tahap terakhir adalah mendapatkan hasil ekstraksi tekstur

# %%
#mendapatkan hasil ekstraksi
dataExtracted,vector = featureExtraction(dataPreprocessed)

# %%
#menampilkan hasi ekstraksi tekstur
print('Extraction Result')
fig = plt.figure(figsize=(10,10))
ax1 = fig.add_subplot(4,2,1)
ax1.set_title('Before')
ax1.set_axis_off()
ax1.imshow(data[0])

ax2 = fig.add_subplot(4,2,2)
ax2.set_title('After')
ax2.set_axis_off()
ax2.imshow(dataExtracted[0],cmap=plt.cm.gray)

ax3 = fig.add_subplot(4,2,3)
ax3.set_title('Before')
ax3.set_axis_off()
ax3.imshow(data[1],)

ax4 = fig.add_subplot(4,2,4)
ax4.set_title('After')
ax4.set_axis_off()
ax4.imshow(dataExtracted[1],cmap=plt.cm.gray)

ax5 = fig.add_subplot(4,2,5)
ax5.set_title('Before')
ax5.set_axis_off()
ax5.imshow(data[2])

ax6 = fig.add_subplot(4,2,6)
ax6.set_title('After')
ax6.set_axis_off()
ax6.imshow(dataExtracted[2],cmap=plt.cm.gray)
plt.show()
# Out:
# Extraction Result

# %% [markdown]
# Mencetak Vector Gambar nya

# %%
#cetak vektor gambar
print("Vector of Image 1 :",vector[0])
print()
print("Vector of Image 2 :",vector[1])
print()
print("Vector of Image 3 :",vector[2])
# Out:
# Vector of Image 1 : [0.02271057 0.01763022 0.01069234 0.00775835 0.00640622 0.00616992
#  0.00638653 0.00750893 0.00921222 0.01182787 0.01598601 0.02945153
#  0.04197188 0.03830275 0.01793544 0.02029182 0.01071204 0.01712482
#  0.00805044 0.00825719 0.00846067 0.01066937 0.01414488 0.01840803
#  0.34348745 0.29044253]
#
# Vector of Image 2 : [0.02271057 0.01763022 0.01069234 0.00775835 0.00640622 0.00616992
#  0.00638653 0.00750893 0.00921222 0.01182787 0.01598601 0.02945153
#  0.04197188 0.03830275 0.01793544 0.02029182 0.01071204 0.01712482
#  0.00805044 0.00825719 0.00846067 0.01066937 0.01414488 0.01840803
#  0.34348745 0.29044253]
#
# Vector of Image 3 : [0.02271057 0.01763022 0.01069234 0.00775835 0.00640622 0.00616992
#  0.00638653 0.00750893 0.00921222 0.01182787 0.01598601 0.02945153
#  0.04197188 0.03830275 0.01793544 0.02029182 0.01071204 0.01712482
#  0.00805044 0.00825719 0.00846067 0.01066937 0.01414488 0.01840803
#  0.34348745 0.29044253]
